# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh190603/image_processing_and_computer_vision/blob/main/Assignment%202/A2Q1a(0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
When we assume that no part overlaps another,
on exchanging the top left and the bottom left parts,
the bottom left part of the final image does not align with the rest of the image

If we overlap a bit of upper left part by the bottom left part (so that both the upper
left and the bottom left parts have the same dimensions (200 pixels x 190 pixels) ),
the parts align just fine, but a gap of dimensions (10 pixels x 190 pixels) remains
at the bottom left of the final image
"""


"""
# Download the test image and utils files
# !wget --no-check-certificate \
    /content/jigsaw.jpg \
    -O jigsaw.jpg


# !wget --no-check-certificate \
    https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/utils/common.py \
    -O common.py
"""

import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image
import matplotlib.pylab as plt

"""
# these imports let you use opencv
import cv2 #opencv itself
#import common #some useful opencv functions
import numpy as np # matrix manipulations
#from google.colab.patches import cv2_imshow

#the following are to do with this interactive notebook code
#%matplotlib inline
from matplotlib import pyplot as plt # this lets you draw inline pictures in the notebooks
import pylab # this allows you to control figure size
"""
#pylab.rcParams['figure.figsize'] = (10.0, 8.0) # this controls figure size in the notebook
url = "/content/jigsaw.jpg"
#image=cv2.imread('jigsaw.jpg')
#image = io.imread(url)
"""
urllib.request.urlretrieve(
  '/content/jigsaw.jpg',
   "gfg.jpg")
"""
image = Image.open("/content/jigsaw.jpg")
#First create an image the same size as our input
#blank_image = np.zeros((input_image.shape), np.uint8)

#blank_image[100:200,100:200,1]=100; #give it a green square
image_1=np.asarray(image)

#new_image=cv2.add(image_1,image) # add the two images together

#plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
#img_1=cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB)
#cv2_imshow(img_1)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

"""
import cv2
import numpy

url="https://drive.google.com/file/d/1khVzqa-6ODJxp0VQvP8VHFih0xtsX-G8/view?usp=sharing"
img = cv2.imread(url)

#raw_data1 = numpy.asarray(url)
raw_data1 = numpy.array(img)
#print(numpy.shape(url))
#print(type(raw_data1))
"""

raw_data1 = image_1.copy()
# reflecting the chick in the midddle laterally
for i in range(150,330) :
    for j in range(515,700) :
        for x in range(3) :
            raw_data1[i][j][x]=image_1[i][700+515-j-1][x]

raw_data2 = raw_data1.copy()

# reflecting the part at the bottom right vertically
for i in range(369,421) :
    for j in range(370,797) :
        for x in range(3) :
            raw_data2[i][j][x]=raw_data1[369+421-i-1][j][x]

raw_data3=raw_data2.copy()

# reflecting vertically the part at the bottom left
# exchanging parts originally present at top left and bottom left

for i in range(0,210) :
    for j in range(0,190) :
        for x in range(3) :
            raw_data3[i][j][x]=raw_data2[409-i][j][x]

raw_data4=raw_data3.copy()

for i in range(210,410) :
    for j in range(0,190) :
        for x in range(3) :
            raw_data4[i][j][x]=raw_data2[i-210][j][x]

plt.imshow(raw_data4)
#cv2.waitKey(0)

#cv2.destroyAllWindows()
